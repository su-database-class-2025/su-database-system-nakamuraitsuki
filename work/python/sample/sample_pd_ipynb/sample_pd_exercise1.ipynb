# %% [markdown]
# # Exercise 1

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
def query_pandas(sql, db):
    """
    Executes a SQL query on a PostgreSQL database and returns the result as a Pandas DataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        pandas.DataFrame: The result of the SQL query as a Pandas DataFrame.
    """

    DATABASE_URL='postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)

    df = pd.read_sql(sql=sql, con=conn)

    return df

# %% [markdown]
# ### Q1: 埼玉県で一番小さい面積の市町村を調べる

# %%
# " "のなかにSQL文を記述
sql = "select name_2, st_area(geom::geography)/1000 as area_km2 \
      from adm2 \
      where name_1='Saitama' \
      order by area_km2 asc \
      limit 1;"

# %%
out = query_pandas(sql, 'gisdb') #specify db name
print(out)
# Out:
#    name_2     area_km2
# 0  Warabi  6587.194115

# %% [markdown]
# ### Q2. 都道府県ごとに一番大きい面積を有する市町村を調べる

# %%
# " "のなかにSQL文を記述
sql = "select adm2.name_1, name_2, st_area(geom::geography)/1000 as area_km2 \
      from adm2 \
      inner join ( \
            select name_1, max(st_area(geom::geography)/1000) as area_km2_max \
            from adm2 \
            group by name_1 \
      ) t_max \
      on adm2.name_1 = t_max.name_1 and st_area(geom::geography)/1000 = t_max.area_km2_max; \
      "

# %%
out = query_pandas(sql, 'gisdb') #specify db name
print(out)
# Out:
#        name_1         name_2      area_km2
# 0       Aichi         Toyota  9.149657e+05
# 1       Akita      Yurihonjō  1.236171e+06
# 2      Aomori          Mutsu  8.621801e+05
# 3       Chiba       Ichihara  3.728970e+05
# 4       Ehime      Kumakōgen  5.824939e+05
# 5       Fukui            Ōno  8.785213e+05
# 6     Fukuoka     Kitakyūshū  4.845351e+05
# 7   Fukushima          Iwaki  1.212133e+06
# 8        Gifu       Takayama  2.173869e+06
# 9       Gunma       Minakami  7.744545e+05
# 10  Hiroshima        Shōbara  1.233377e+06
# 11   Hokkaido         Ashoro  1.406101e+06
# 12      Hyōgo        Toyooka  6.948764e+05
# 13    Ibaraki     Hitachiōta  3.730510e+05
# 14   Ishikawa        Hakusan  7.611476e+05
# 15      Iwate     Ichinoseki  1.139296e+06
# 16     Kagawa      Takamatsu  3.864838e+05
# 17  Kagoshima  Satsumasendai  7.128770e+05
# 18   Kanagawa       Yokohama  4.230858e+05
# 19      Kochi       Shimanto  6.356620e+05
# 20   Kumamoto        Amakusa  8.045475e+05
# ...

# %% [markdown]
# ### Q3. 都道府県ごとに市町村の総数が多い順に並べる

# %%
# " "のなかにSQL文を記述
sql = "select name_1, count(*) as count \
      from adm2 \
      group by name_1 \
      order by count desc;"

# %%
out = query_pandas(sql, 'gisdb') #specify db name
print(out)
# Out:
#        name_1  count
# 0    Hokkaido    180
# 1      Nagano     82
# 2     Saitama     70
# 3     Fukuoka     66
# 4       Aichi     64
# 5   Fukushima     60
# 6       Chiba     56
# 7       Tokyo     53
# 8    Kumamoto     48
# 9   Kagoshima     46
# 10    Ibaraki     45
# 11      Osaka     43
# 12       Gifu     43
# 13   Shizuoka     43
# 14    Okinawa     42
# 15      Hyōgo     41
# 16     Aomori     40
# 17       Nara     39
# 18      Gunma     38
# 19     Miyagi     36
# 20      Kochi     35
# 21   Yamagata     35
# 22      Iwate     35
# 23   Kanagawa     33
# 24    Niigata     31
# 25    Tochigi     31
# 26    Okayama     30
# 27   Miyazaki     30
# 28   Wakayama     29
# 29  Yamanashi     28
# 30        Mie     28
# 31      Shiga     27
# 32      Kyoto     26
# 33      Akita     25
# 34  Tokushima     24
# 35   Naoasaki     23
# 36  Hiroshima     23
# 37    Shimane     22
# 38       Saga     20
# 39      Ehime     20
# 40  Yamaguchi     20
# 41   Ishikawa     19
# ...

# %% [markdown]
# ### Q4. 都道府県ごとに村の総数が多い順に並べる

# %%
# " "のなかにSQL文を記述
sql = "select name_1, count(*) as Machi_count \
      from ( \
        select * from adm2 \
        where type_2 = 'Machi'\
      ) as adm_machi \
      group by name_1 \
      order by Machi_count desc;"

# %%
out = query_pandas(sql, 'gisdb') #specify db name
print(out)
# Out:
#        name_1  machi_count
# 0    Hokkaido          133
# 1     Fukuoka           35
# 2   Fukushima           34
# 3     Saitama           30
# 4       Aichi           27
# 5      Nagano           27
# 6   Kagoshima           27
# 7    Kumamoto           27
# 8      Aomori           23
# 9      Miyagi           23
# 10      Gunma           22
# 11   Yamagata           22
# 12   Shizuoka           20
# 13      Chiba           20
# 14   Wakayama           20
# 15      Kochi           20
# 16       Gifu           19
# 17   Miyazaki           19
# 18    Tochigi           17
# 19       Nara           17
# 20      Iwate           16
# 21  Tokushima           15
# 22   Kanagawa           14
# 23    Tottori           14
# 24    Shimane           13
# 25    Okinawa           13
# 26      Shiga           13
# 27    Okayama           13
# 28      Hyōgo           13
# 29        Mie           12
# 30    Ibaraki           10
# 31      Kyoto           10
# 32      Akita           10
# ...
